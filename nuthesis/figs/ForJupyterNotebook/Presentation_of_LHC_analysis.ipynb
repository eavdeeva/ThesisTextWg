# %% [markdown]
# This notebook is a summary of my analysis of Large Hadron Collider data as I'm going to present it for my Ph.D. defense. This presentation is aimed for an audience that has a college-level math background but may not necesserily have special knowledge of particle physics.
#
# All the necessary particle physics terms essential for understanding of the presentation content will be introduced as we go along.
#
# If you are interested to learn a specific part of this summary in more detail, you are welcome to read through an appropriate chapter of the [dissertation](https://github.com/eavdeeva/ThesisTextWg/blob/master/nuthesis/examples/nuthesis_20170808.pdf), and also through sources quoted there if you want to go deeper.
#
# Regardless the level of your understanding of particle physics, you are welcome to ask me any questions you may have since they will help me to prepare better for my defense. Don't hesitate to ask something you may think is too trivial. Those are exactly kind of questions I have the least experiece answering while they are not at all the least probable to appear.
#
# Ok, let us get started. The topic of my dissertation is
#
# # The Measurement of the $W\gamma$ Cross Section at 8 TeV of LHC Energy
# ## Candidate: Ekaterina Avdeeva; adviser: Ilya Kravchenko
# ### University of Nebraska - Lincoln
# - - -

# %% [markdown]
# ## Outline
#
#
# 1) First, I will give a very brief introduction into the field of particle physics, explain what '$W\gamma$' means, and emphasize why this measurement is important.
#
#
# 2) Second, I will show images of the Large Hadron Collider and the detector that was used to register the products of collisions/ The detector used in this work is Compact Muon Solenoid or CMS
#
#
# 3) After that, I will go to the major steps of the analysis itself and present the results
#
#
# 4) Finally, I will discuss the results of the measurement and draw the conclusions
# - - -

# %% [markdown]
# ## 1. Introduction to theory
# - - -
# ### 1.1. The following image demonstrates the atom structure.

# %%
from IPython.display import Image
Image(filename='Theory_StandardModel01.png')

# %% [markdown]
# There is an atom that consists of a nucleous and an electron orbiting around it. The electron is not known to have any structure, thus, we call it a *fundamental particle*. At the same time, the nucleous consists of protons and neutrons. Each proton and neutron is a composite particle: they consists of quarks. Quarks are not known to have any structure, thus, they are elementary particles too.
#
# Let us look at the same picture with the table of all fundamental particles.

# %%
Image(filename='Theory_StandardModel02.png')

# %% [markdown]
# Here is the table of the elementary particles. There are six quarks ($u$,$d$,$s$,$c$,$b$ and $t$), six leptons ($e$,$\mu$,$\tau$, and corresponding neutrinos), four types of gauge bosons (photon, gluon, $W$ and $Z$ bosons), and the Higgs boson.
#
# Protons consist of three quarks ($uud$), and neutrons consist of three quarks ($udd$). Quarks $u$ and $d$ and electrons are the only elementary particles that comprise all everyday matter.
#
# They all three, with an electron neutrino, comprise the first column in the elementary particle table. Particles in the first column are called the first generation particles in the Standard Model.
#
# In high energy collisions, particles from the 2nd and the 3rd generations can be created too. However, they are too heavy, and decay immediately.
#
# Now

# %% [markdown]
# - - -
# ### 1.2. What is going on during the collision of two highly energetic protons

# %%
Image(filename='Theory_ppCollision.png')

# %% [markdown]
# Let us take a closer look into the proton structure. We just discussed that protons consist of three quarks: $uud$. However, it is not the whole story. These three quarks interact with each other by exchanging gluons (curved lines), and these gluons produce quark-antiquark pairs that are called *sea* quarks and antiquarks. In contrast, the three original quarks are called *valence* quarks. All these proton constituents, valence quarks, sea quarks and antiquarks, and gluons, are called *partons*.
#
# When two protons smash, usually one parton from one of the protons interact with another parton from the other proton. It can be quark-quark ($qq$), quark-gluon ($qg$), quark-antiquark ($q\bar{q}$) collision etc. At the moment of a collision, these two partons disappear, and a new particles or a number of particles are born. At this particular figure, a $Z$ boson is born and further decay into $\mu^+ \mu^-$ pair (and each of these muons will decay microseconds later). In another collision it could be another primary particle, or a $Z$ boson again but decaying into other particles.
#
# The collision process is completely probabilistic. While certain collision scenarios are much more likely to happen than others, there is no way to predict what exactly is going to happen during the given collision.
#
# The question is can we understand what was the process at least AFTER it already happened. This whole notebook will try to bring more insight to answer this question. I will start with explaining what particle collision process I'm looking for.

# %% [markdown]
# - - -
#
# ### 1.3. $W\gamma$ process with further $W$ decaying as $W\rightarrow e\nu_e$ or $W\rightarrow \mu\nu_{\mu}$
#
# In this analysis, I'm searching for such cases of proton-proton collisions denoted as
#
# $q\bar{q'} \rightarrow W \gamma \rightarrow l\nu\gamma$ or $q\bar{q'} \rightarrow W \rightarrow l\nu\gamma$,
#
# where $q$ is a quark from one of the colliding protons, $\bar{q'}$ is an antiquark from the other colliding proton, $W$ is a $W$ boson, $\gamma$ is a photon, $l$ could be either an electron ($e$) or a muon ($\mu$), and $\nu$ is neutrino.
#
# The process can be representaed graphically by co-called *Feynman diagrams*. While there is an infinite number of Feynman diagrams that contribute to this (or any) process, the most significant contribution comes from only four of them:

# %%
Image(filename='feynmWg_LO_01.png')
